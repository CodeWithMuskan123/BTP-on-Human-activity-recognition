# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
from keras.models import Sequential
from keras.layers import LSTM ,Dense, Dropout
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD, Adam
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
train_path = "./archive/UCI_HAR_Dataset/train/"
test_path = "./archive/UCI_HAR_Dataset/test/"
features_path = "./archive/UCI_HAR_Dataset/features.txt"

# %%
features = []
with open(features_path) as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
print("No. of unique features:{}".format(len(set(features))))
# Out:
# No of Features: 561
# No. of unique features:477

# %%
#LABELS
labels = {1: 'WALKING', 
          2:'WALKING_UPSTAIRS',
          3:'WALKING_DOWNSTAIRS',
          4:'SITTING',
          5:'STANDING',
          6:'LAYING'}

# %%
re=[]
for i , f in enumerate(features):
    for j in range(i+1 , len(features)):
        if features[i]==features[j] and features[i] not in re:
            re.append(features[i])

# %%
for i , f in enumerate(features):
    features[i] = ''.join(e for e in f if e not in ['(',')' , '-' , ','])

# %%
train = pd.read_csv(train_path + "X_train.txt" , delim_whitespace=True ,header=None)
train.columns = features
train['subject'] = pd.read_csv(train_path + 'subject_train.txt' , header=None , squeeze=True)
test = pd.read_csv(test_path + "X_test.txt" , delim_whitespace=True ,header=None)
test.columns = features
test['subject'] = pd.read_csv(test_path + 'subject_test.txt' , header=None , squeeze=True)

# %%
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    fBodyBodyGyroJerkMagskewness  fBodyBodyGyroJerkMagkurtosis  \
# 0                     -0.298676                     -0.710304
# 1                     -0.595051                     -0.861499
# 2                     -0.390748                     -0.760104
# 3                     -0.117290                     -0.482845
# 4                     -0.351471                     -0.699205
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
# 3                 -0.036788                         -0.012892
# 4                  0.123320                          0.122542
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
# 3                       0.640011                          -0.485366
# 4                       0.693578                          -0.615971
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject
# 0          -0.841247           0.179941          -0.058627        1
# 1          -0.844788           0.180289          -0.054317        1
# 2          -0.848933           0.180637          -0.049118        1
# 3          -0.848649           0.181935          -0.047663        1
# 4          -0.847865           0.185151          -0.043892        1
#
# [5 rows x 562 columns]

# %%
test.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1       0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2       0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3       0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4       0.274833      -0.027848      -0.129527     -0.993852     -0.967445
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.667683     -0.952501     -0.925249     -0.674302     -0.894088  ...
# 1     -0.944958     -0.986799     -0.968401     -0.945823     -0.894088  ...
# 2     -0.962748     -0.994403     -0.970735     -0.963483     -0.939260  ...
# 3     -0.967091     -0.995274     -0.974471     -0.968897     -0.938610  ...
# 4     -0.978295     -0.994111     -0.965953     -0.977346     -0.938610  ...
#
#    fBodyBodyGyroJerkMagskewness  fBodyBodyGyroJerkMagkurtosis  \
# 0                     -0.330370                     -0.705974
# 1                     -0.121845                     -0.594944
# 2                     -0.190422                     -0.640736
# 3                     -0.344418                     -0.736124
# 4                     -0.534685                     -0.846595
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                  0.006462                          0.162920
# 1                 -0.083495                          0.017500
# 2                 -0.034956                          0.202302
# 3                 -0.017067                          0.154438
# 4                 -0.002223                         -0.040046
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.825886                           0.271151
# 1                      -0.434375                           0.920593
# 2                       0.064103                           0.145068
# 3                       0.340134                           0.296407
# 4                       0.736715                          -0.118545
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject
# 0          -0.720009           0.276801          -0.057978        2
# 1          -0.698091           0.281343          -0.083898        2
# 2          -0.702771           0.280083          -0.079346        2
# 3          -0.698954           0.284114          -0.077108        2
# 4          -0.692245           0.290722          -0.073857        2
#
# [5 rows x 562 columns]

# %%
y_train = pd.read_csv(train_path + 'y_train.txt' , names=['Activity'] , squeeze=True)
y_test = pd.read_csv(test_path + 'y_test.txt' , names=['Activity'] , squeeze=True)

# %%
train['Activity']= y_train
test['Activity'] = y_test
train['ActivityName'] = y_train.map(labels)
test['ActivityName']  = y_test.map(labels)

# %%
print("The number of missing values in Training Data:" , train.isnull().values.sum())
print("The number of missing values in Testing Data:" , test.isnull().values.sum())
# Out:
# The number of missing values in Training Data: 0
# The number of missing values in Testing Data: 0

# %%
print("The number of duplicate values in Training Data:" , train.duplicated().sum())
print("The number of duplicate values in Testing Data:" , test.duplicated().sum())
# Out:
# The number of duplicate values in Training Data: 0
# The number of duplicate values in Testing Data: 0

# %%
plt.figure(figsize=(10,5))
plt.title('Subject Wise Data Distribution')
sns.countplot(x='subject' , data=train )
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.title('Activity based Subject Distribution')
sns.countplot(x='subject' , hue='ActivityName', data=train )
plt.show()

# %%
accFeat=[]
for feat in features:
    if feat.find('BodyAcc') != -1 and feat.find('Magmean') !=-1 and feat.find('Freq')==-1:
        accFeat.append(feat)

# %%
def plotFacetGrid(feature, height):
    
    plt.figure(figsize=(10,10))
    facetgrid=sns.FacetGrid(train , hue='ActivityName',height=height,aspect=3)
    facetgrid.map(sns.distplot ,feature, hist=False).add_legend()
    plt.show()

# %%
for f in accFeat:
    plotFacetGrid(f,3)
# Out:
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/kriti/.local/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
def boxplot(feature , ylabel):
    
    plt.figure(figsize=(5,5))
    sns.boxplot(x='ActivityName', y=feature, data=train , showfliers=False )
    plt.ylabel(ylabel)
    plt.axhline(y=-0.8, xmin=0.1, xmax=0.9,dashes=(5,5), c='g') #line separating both type of activities
    plt.xticks(rotation=90)

# %%
for f in accFeat:
    boxplot(f , f[5:])

# %%
from sklearn.manifold import TSNE

# %%
def plotTsne(X,y,perplexity):
    
    #performing dim reduction
    X_reduce = TSNE(verbose=2, perplexity=perplexity).fit_transform(X)
    
    print('Creating plot for this t-sne visualization..')
    data={'x':X_reduce[:,0],
          'y':X_reduce[:,1],
         'label':y}
    #preparing dataframe from reduced data
    df = pd.DataFrame(data)
    
    #draw the plot
    sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
    
    plt.title("perplexity : {}".format(perplexity))
    img_name = 'TSNE_perp_{}.png'.format(perplexity)
    print('saving this plot as image in present working directory...')
    plt.savefig(img_name)
    plt.show()
    print('Done')

# %%
X= train.drop(['ActivityName'],axis=1)
y= train['ActivityName']
perplexity=[2,5,10]

# %%
for p in perplexity:
    plotTsne(X,y,perplexity=p)
# Out:
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.012s...
# [t-SNE] Computed neighbors for 7352 samples in 4.721s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.721133
# [t-SNE] Computed conditional probabilities in 0.172s
# [t-SNE] Iteration 50: error = 124.5530014, gradient norm = 0.0388847 (50 iterations in 7.259s)
# [t-SNE] Iteration 100: error = 104.6524353, gradient norm = 0.0314815 (50 iterations in 5.328s)
# [t-SNE] Iteration 150: error = 98.0054245, gradient norm = 0.0246648 (50 iterations in 5.994s)
# [t-SNE] Iteration 200: error = 94.1311340, gradient norm = 0.0182473 (50 iterations in 7.877s)
# [t-SNE] Iteration 250: error = 91.4346771, gradient norm = 0.0185380 (50 iterations in 8.030s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 91.434677
# [t-SNE] Iteration 300: error = 4.0021577, gradient norm = 0.0015555 (50 iterations in 6.388s)
# [t-SNE] Iteration 350: error = 3.0937209, gradient norm = 0.0010070 (50 iterations in 5.398s)
# [t-SNE] Iteration 400: error = 2.6592035, gradient norm = 0.0007238 (50 iterations in 4.999s)
# [t-SNE] Iteration 450: error = 2.3899822, gradient norm = 0.0005796 (50 iterations in 1.808s)
# [t-SNE] Iteration 500: error = 2.2027559, gradient norm = 0.0004834 (50 iterations in 1.815s)
# [t-SNE] Iteration 550: error = 2.0618618, gradient norm = 0.0004210 (50 iterations in 1.775s)
# [t-SNE] Iteration 600: error = 1.9497979, gradient norm = 0.0003656 (50 iterations in 1.811s)
# [t-SNE] Iteration 650: error = 1.8577681, gradient norm = 0.0003375 (50 iterations in 1.403s)
# [t-SNE] Iteration 700: error = 1.7802955, gradient norm = 0.0003076 (50 iterations in 1.546s)
# [t-SNE] Iteration 750: error = 1.7133831, gradient norm = 0.0002808 (50 iterations in 1.590s)
# [t-SNE] Iteration 800: error = 1.6552103, gradient norm = 0.0002619 (50 iterations in 1.747s)
# [t-SNE] Iteration 850: error = 1.6036286, gradient norm = 0.0002442 (50 iterations in 1.445s)
# [t-SNE] Iteration 900: error = 1.5575453, gradient norm = 0.0002280 (50 iterations in 1.455s)
# [t-SNE] Iteration 950: error = 1.5162767, gradient norm = 0.0002132 (50 iterations in 1.607s)
# [t-SNE] Iteration 1000: error = 1.4787031, gradient norm = 0.0002009 (50 iterations in 1.458s)
# [t-SNE] KL divergence after 1000 iterations: 1.478703
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.010s...
# [t-SNE] Computed neighbors for 7352 samples in 3.017s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.127482
# [t-SNE] Computed conditional probabilities in 0.104s
# [t-SNE] Iteration 50: error = 112.8256912, gradient norm = 0.0365369 (50 iterations in 3.171s)
# [t-SNE] Iteration 100: error = 92.8207550, gradient norm = 0.0193786 (50 iterations in 2.083s)
# [t-SNE] Iteration 150: error = 86.9092865, gradient norm = 0.0134933 (50 iterations in 1.799s)
# [t-SNE] Iteration 200: error = 83.5752106, gradient norm = 0.0099336 (50 iterations in 1.413s)
# [t-SNE] Iteration 250: error = 81.3341522, gradient norm = 0.0093664 (50 iterations in 1.922s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.334152
# [t-SNE] Iteration 300: error = 3.2675624, gradient norm = 0.0014508 (50 iterations in 1.716s)
# [t-SNE] Iteration 350: error = 2.4993567, gradient norm = 0.0007578 (50 iterations in 2.456s)
# [t-SNE] Iteration 400: error = 2.1062276, gradient norm = 0.0005320 (50 iterations in 1.784s)
# [t-SNE] Iteration 450: error = 1.8815011, gradient norm = 0.0004157 (50 iterations in 1.908s)
# [t-SNE] Iteration 500: error = 1.7320385, gradient norm = 0.0003426 (50 iterations in 2.401s)
# [t-SNE] Iteration 550: error = 1.6234843, gradient norm = 0.0002890 (50 iterations in 2.248s)
# [t-SNE] Iteration 600: error = 1.5397209, gradient norm = 0.0002513 (50 iterations in 2.387s)
# [t-SNE] Iteration 650: error = 1.4724516, gradient norm = 0.0002237 (50 iterations in 2.020s)
# [t-SNE] Iteration 700: error = 1.4167360, gradient norm = 0.0002029 (50 iterations in 1.880s)
# [t-SNE] Iteration 750: error = 1.3694851, gradient norm = 0.0001848 (50 iterations in 1.843s)
# [t-SNE] Iteration 800: error = 1.3290889, gradient norm = 0.0001704 (50 iterations in 1.812s)
# [t-SNE] Iteration 850: error = 1.2939917, gradient norm = 0.0001595 (50 iterations in 1.804s)
# [t-SNE] Iteration 900: error = 1.2630494, gradient norm = 0.0001482 (50 iterations in 2.185s)
# [t-SNE] Iteration 950: error = 1.2355119, gradient norm = 0.0001404 (50 iterations in 1.744s)
# [t-SNE] Iteration 1000: error = 1.2107725, gradient norm = 0.0001300 (50 iterations in 1.768s)
# [t-SNE] KL divergence after 1000 iterations: 1.210773
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 3.314s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.357802
# [t-SNE] Computed conditional probabilities in 0.171s
# [t-SNE] Iteration 50: error = 103.0298233, gradient norm = 0.0361687 (50 iterations in 2.552s)
# [t-SNE] Iteration 100: error = 83.8861389, gradient norm = 0.0133108 (50 iterations in 2.039s)
# [t-SNE] Iteration 150: error = 78.6925888, gradient norm = 0.0097323 (50 iterations in 1.684s)
# [t-SNE] Iteration 200: error = 75.9206314, gradient norm = 0.0081235 (50 iterations in 1.726s)
# [t-SNE] Iteration 250: error = 74.0770340, gradient norm = 0.0055985 (50 iterations in 1.585s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.077034
# [t-SNE] Iteration 300: error = 2.7100303, gradient norm = 0.0013864 (50 iterations in 1.643s)
# [t-SNE] Iteration 350: error = 2.0481136, gradient norm = 0.0006637 (50 iterations in 1.681s)
# [t-SNE] Iteration 400: error = 1.7085233, gradient norm = 0.0004384 (50 iterations in 1.782s)
# [t-SNE] Iteration 450: error = 1.5143008, gradient norm = 0.0003237 (50 iterations in 1.653s)
# [t-SNE] Iteration 500: error = 1.3905462, gradient norm = 0.0002580 (50 iterations in 1.896s)
# [t-SNE] Iteration 550: error = 1.3039474, gradient norm = 0.0002181 (50 iterations in 2.286s)
# [t-SNE] Iteration 600: error = 1.2388933, gradient norm = 0.0001872 (50 iterations in 1.826s)
# [t-SNE] Iteration 650: error = 1.1880001, gradient norm = 0.0001630 (50 iterations in 2.043s)
# [t-SNE] Iteration 700: error = 1.1469173, gradient norm = 0.0001489 (50 iterations in 2.089s)
# [t-SNE] Iteration 750: error = 1.1128175, gradient norm = 0.0001356 (50 iterations in 2.191s)
# [t-SNE] Iteration 800: error = 1.0840381, gradient norm = 0.0001262 (50 iterations in 2.310s)
# [t-SNE] Iteration 850: error = 1.0594566, gradient norm = 0.0001178 (50 iterations in 1.613s)
# [t-SNE] Iteration 900: error = 1.0384905, gradient norm = 0.0001089 (50 iterations in 1.283s)
# [t-SNE] Iteration 950: error = 1.0202439, gradient norm = 0.0001025 (50 iterations in 1.548s)
# [t-SNE] Iteration 1000: error = 1.0044105, gradient norm = 0.0000992 (50 iterations in 2.352s)
# [t-SNE] KL divergence after 1000 iterations: 1.004411
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %%
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

"-----------------------RAW DATA--------------------------------------"

# Raw data signals
# Signals are from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
path= "./archive/UCI_HAR_Dataset/"

# %%
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

"----------------------------LOAD SIGNAL---------------------------------------------"

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = path+subset+'/Inertial Signals/'+signal+'_'+subset+'.txt'
        signals_data.append(
            _read_csv(filename).values
        ) 

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

"-------------------------CONFUSION MATRIX----------------------------------------------"

# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])


"----------------------------LOAD Y-------------------------------------------------------"



def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of 
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = path+subset+'/y_'+subset+'.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).values



"---------------------------------LOAD DATA---------------------------------------------"


def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test


"---------------------------------COUNT CLASSES--------------------------------------------"

# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
epochs = 30
batch_size = 16
n_hidden = 32

# %%
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %%
model = Sequential()
# Configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                5376
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 198
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=epochs)
# Out:
# Epoch 1/30
# 460/460 [==============================] - 26s 46ms/step - loss: 1.0826 - accuracy: 0.5218 - val_loss: 0.8028 - val_accuracy: 0.6451
# Epoch 2/30
# 460/460 [==============================] - 16s 34ms/step - loss: 0.7248 - accuracy: 0.6730 - val_loss: 0.6926 - val_accuracy: 0.6990
# Epoch 3/30
# 460/460 [==============================] - 16s 34ms/step - loss: 0.5969 - accuracy: 0.7538 - val_loss: 0.6733 - val_accuracy: 0.7533
# Epoch 4/30
# 460/460 [==============================] - 17s 37ms/step - loss: 0.4887 - accuracy: 0.8255 - val_loss: 0.6434 - val_accuracy: 0.7428
# Epoch 5/30
# 460/460 [==============================] - 17s 37ms/step - loss: 0.3916 - accuracy: 0.8747 - val_loss: 0.4701 - val_accuracy: 0.8521
# Epoch 6/30
# 460/460 [==============================] - 23s 51ms/step - loss: 0.3235 - accuracy: 0.9044 - val_loss: 0.4865 - val_accuracy: 0.8578
# Epoch 7/30
# 460/460 [==============================] - 39s 85ms/step - loss: 0.2713 - accuracy: 0.9153 - val_loss: 0.4767 - val_accuracy: 0.8561
# Epoch 8/30
# 460/460 [==============================] - 38s 82ms/step - loss: 0.2500 - accuracy: 0.9242 - val_loss: 0.4605 - val_accuracy: 0.8789
# Epoch 9/30
# 460/460 [==============================] - 35s 76ms/step - loss: 0.2118 - accuracy: 0.9268 - val_loss: 0.4641 - val_accuracy: 0.8656
# Epoch 10/30
# 460/460 [==============================] - 35s 77ms/step - loss: 0.2032 - accuracy: 0.9343 - val_loss: 0.7417 - val_accuracy: 0.8341
# Epoch 11/30
# 460/460 [==============================] - 34s 74ms/step - loss: 0.1924 - accuracy: 0.9378 - val_loss: 0.4901 - val_accuracy: 0.8744
# Epoch 12/30
# 460/460 [==============================] - 34s 74ms/step - loss: 0.1783 - accuracy: 0.9419 - val_loss: 0.4058 - val_accuracy: 0.8935
# Epoch 13/30
# 460/460 [==============================] - 34s 75ms/step - loss: 0.1804 - accuracy: 0.9421 - val_loss: 0.4162 - val_accuracy: 0.8839
# Epoch 14/30
# 460/460 [==============================] - 35s 76ms/step - loss: 0.1833 - accuracy: 0.9396 - val_loss: 0.4132 - val_accuracy: 0.8775
# Epoch 15/30
# 460/460 [==============================] - 38s 83ms/step - loss: 0.1744 - accuracy: 0.9419 - val_loss: 0.6899 - val_accuracy: 0.8639
# Epoch 16/30
# 460/460 [==============================] - 35s 75ms/step - loss: 0.1581 - accuracy: 0.9464 - val_loss: 0.5083 - val_accuracy: 0.8863
# Epoch 17/30
# 460/460 [==============================] - 34s 73ms/step - loss: 0.1672 - accuracy: 0.9415 - val_loss: 0.5411 - val_accuracy: 0.8802
# Epoch 18/30
# 460/460 [==============================] - 32s 69ms/step - loss: 0.1863 - accuracy: 0.9385 - val_loss: 0.4196 - val_accuracy: 0.9013
# Epoch 19/30
# 460/460 [==============================] - 31s 68ms/step - loss: 0.1606 - accuracy: 0.9444 - val_loss: 0.4104 - val_accuracy: 0.8955
# Epoch 20/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.1485 - accuracy: 0.9472 - val_loss: 0.3824 - val_accuracy: 0.8985
# Epoch 21/30
# 460/460 [==============================] - 31s 67ms/step - loss: 0.1604 - accuracy: 0.9416 - val_loss: 0.4563 - val_accuracy: 0.8829
# Epoch 22/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.1476 - accuracy: 0.9489 - val_loss: 0.4379 - val_accuracy: 0.8894
# Epoch 23/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.1561 - accuracy: 0.9422 - val_loss: 0.4567 - val_accuracy: 0.8880
# Epoch 24/30
# 460/460 [==============================] - 32s 70ms/step - loss: 0.1457 - accuracy: 0.9483 - val_loss: 0.7183 - val_accuracy: 0.8829
# Epoch 25/30
# 460/460 [==============================] - 32s 70ms/step - loss: 0.1396 - accuracy: 0.9471 - val_loss: 0.6383 - val_accuracy: 0.8829
# Epoch 26/30
# 460/460 [==============================] - 31s 67ms/step - loss: 0.1549 - accuracy: 0.9490 - val_loss: 0.6377 - val_accuracy: 0.8867
# Epoch 27/30
# 460/460 [==============================] - 32s 69ms/step - loss: 0.1438 - accuracy: 0.9482 - val_loss: 0.4771 - val_accuracy: 0.8992
# Epoch 28/30
# 460/460 [==============================] - 31s 68ms/step - loss: 0.1439 - accuracy: 0.9489 - val_loss: 0.6232 - val_accuracy: 0.8985
# Epoch 29/30
# 460/460 [==============================] - 31s 68ms/step - loss: 0.1442 - accuracy: 0.9482 - val_loss: 0.5475 - val_accuracy: 0.9009
# Epoch 30/30
# 460/460 [==============================] - 31s 68ms/step - loss: 0.1486 - accuracy: 0.9471 - val_loss: 0.7888 - val_accuracy: 0.8795
